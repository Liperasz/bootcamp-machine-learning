# %% [markdown]
# # Pratica usando o Kaggle
# Aqui estou usando o kaggle porque ele possui essa função muito interessante de importar datasets para o projeto de forma extremamente fácil

# %%
import pandas as pd

# %% [markdown]
# ## Ponto Importante
# O primeiro read_csv está com o caminho que eu utilizei no Kaggle, porém quando eu baixei manualmente os arquivos
# eu criei o segundo read para que fosse possivel ler quando baixar o código também. Por padrão, vou deixar o read
# do kaggle desativado, mas saiba que ele que é o original.

# %%
# importando o csv direto do projeto do kaggle (../ serve para o interpretador entender que tem que voltar uma pasta para depois achar a pasta input/...)
# df = pd.read_csv('../input/uber-ride-analytics-dashboard/ncr_ride_bookings.csv')

# %%
# Lendo o csv que foi baixado localmente
df = pd.read_csv('ncr_ride_bookings.csv')

# %%
df.head()
# Out:
#          Date      Time    Booking ID   Booking Status   Customer ID  \
# 0  2024-03-23  12:29:38  "CNR5884300"  No Driver Found  "CID1982111"
# 1  2024-11-29  18:01:39  "CNR1326809"       Incomplete  "CID4604802"
# 2  2024-08-23  08:56:10  "CNR8494506"        Completed  "CID9202816"
# 3  2024-10-21  17:17:25  "CNR8906825"        Completed  "CID2610914"
# 4  2024-09-16  22:08:00  "CNR1950162"        Completed  "CID9933542"
#
#     Vehicle Type      Pickup Location      Drop Location  Avg VTAT  Avg CTAT  \
# 0          eBike          Palam Vihar            Jhilmil       NaN       NaN
# 1       Go Sedan        Shastri Nagar  Gurgaon Sector 56       4.9      14.0
# 2           Auto              Khandsa      Malviya Nagar      13.4      25.8
# 3  Premier Sedan  Central Secretariat           Inderlok      13.1      28.5
# 4           Bike     Ghitorni Village        Khan Market       5.3      19.6
#
#    ...  Reason for cancelling by Customer Cancelled Rides by Driver  \
# ...

# %%
# removendo valores nulos
df2 = df.dropna()
df2.head()
# Out:
# Empty DataFrame
# Columns: [Date, Time, Booking ID, Booking Status, Customer ID, Vehicle Type, Pickup Location, Drop Location, Avg VTAT, Avg CTAT, Cancelled Rides by Customer, Reason for cancelling by Customer, Cancelled Rides by Driver, Driver Cancellation Reason, Incomplete Rides, Incomplete Rides Reason, Booking Value, Ride Distance, Driver Ratings, Customer Rating, Payment Method]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# Aparentemente todas as linhas possuem valores nulos

# %%
# Ordenando pelo status do agendamento
df = df.sort_values(by=['Booking Status'], ascending=True)
df.head()
# Out:
#               Date      Time    Booking ID         Booking Status  \
# 26252   2024-07-16  23:58:45  "CNR2573708"  Cancelled by Customer
# 37907   2024-07-12  19:35:39  "CNR4594234"  Cancelled by Customer
# 138694  2024-07-08  17:15:07  "CNR4877911"  Cancelled by Customer
# 73634   2024-05-13  09:43:52  "CNR1573974"  Cancelled by Customer
# 117229  2024-02-21  19:06:03  "CNR3491912"  Cancelled by Customer
#
#          Customer ID   Vehicle Type  Pickup Location   Drop Location  \
# 26252   "CID1797955"          eBike      Gwal Pahari     Vasant Kunj
# 37907   "CID6856185"           Auto     Adarsh Nagar   Basai Dhankot
# 138694  "CID2959427"  Premier Sedan    Shastri Nagar      Peeragarhi
# 73634   "CID8480820"        Go Mini      Kirti Nagar  DLF City Court
# 117229  "CID9444043"           Auto  Noida Sector 18    Jahangirpuri
#
#         Avg VTAT  Avg CTAT  ...  Reason for cancelling by Customer  \
# 26252       17.9       NaN  ...             Driver asked to cancel
# ...

# %%
# Agrupando pelo status
group = df.groupby(['Booking Status'])
group.head()
# Out:
#               Date      Time    Booking ID         Booking Status  \
# 26252   2024-07-16  23:58:45  "CNR2573708"  Cancelled by Customer
# 37907   2024-07-12  19:35:39  "CNR4594234"  Cancelled by Customer
# 138694  2024-07-08  17:15:07  "CNR4877911"  Cancelled by Customer
# 73634   2024-05-13  09:43:52  "CNR1573974"  Cancelled by Customer
# 117229  2024-02-21  19:06:03  "CNR3491912"  Cancelled by Customer
# 53921   2024-02-06  23:32:12  "CNR4488761"    Cancelled by Driver
# 106776  2024-07-08  11:01:08  "CNR6651445"    Cancelled by Driver
# 123429  2024-03-17  05:59:09  "CNR9850172"    Cancelled by Driver
# 30735   2024-08-04  20:27:15  "CNR5425058"    Cancelled by Driver
# 103600  2024-05-02  04:44:09  "CNR6043983"    Cancelled by Driver
# 80754   2024-02-23  17:30:17  "CNR2716828"              Completed
# 80635   2024-01-17  18:04:32  "CNR4865735"              Completed
# 102722  2024-07-06  20:02:05  "CNR7830472"              Completed
# ...

# %%
# Cortando todas as linhas em que o status é diferente de completo
df = df[df['Booking Status'] == 'Completed']
df.head()
# Out:
#               Date      Time    Booking ID Booking Status   Customer ID  \
# 80754   2024-02-23  17:30:17  "CNR2716828"      Completed  "CID4758660"
# 80635   2024-01-17  18:04:32  "CNR4865735"      Completed  "CID1199848"
# 102722  2024-07-06  20:02:05  "CNR7830472"      Completed  "CID2053486"
# 82542   2024-05-24  09:17:13  "CNR3476756"      Completed  "CID2329124"
# 102723  2024-08-04  12:01:45  "CNR8099368"      Completed  "CID9075206"
#
#          Vehicle Type   Pickup Location Drop Location  Avg VTAT  Avg CTAT  \
# 80754         Go Mini            Rohini  Shivaji Park       6.3      31.9
# 80635         Go Mini  Ghitorni Village     Pitampura       6.7      16.1
# 102722  Premier Sedan        India Gate  Adarsh Nagar      11.5      26.8
# 82542        Go Sedan          RK Puram       Manesar       8.6      17.6
# 102723          eBike  Ghitorni Village    Ardee City       6.3      35.9
#
#         ...  Reason for cancelling by Customer Cancelled Rides by Driver  \
# ...
