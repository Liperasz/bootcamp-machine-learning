# %%
import pandas as pd
import tensorflow as tf
import sklearn

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
# Out:
# 2026-02-05 18:07:18.667216: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-02-05 18:07:18.675955: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-05 18:07:19.078184: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# caminho para o dataset
path = '../archives/autos.csv'

# importando o dataset
df = pd.read_csv(path, encoding='ISO-8859-1')
df
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3TÜRER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %% [markdown]
# ### Removendo colunas desnecessárias

# %%
# apagando as colunas que não são importantes para a previsão do preço
df = df.drop('dateCrawled', axis=1)
df = df.drop('dateCreated', axis=1)
df = df.drop('nrOfPictures', axis=1)
df = df.drop('postalCode', axis=1)
df = df.drop('lastSeen', axis=1)
df
# Out:
#                                                 name  seller offerType  price  \
# 0                                         Golf_3_1.6  privat   Angebot    480
# 1                               A5_Sportback_2.7_Tdi  privat   Angebot  18300
# 2                     Jeep_Grand_Cherokee_"Overland"  privat   Angebot   9800
# 3                                 GOLF_4_1_4__3TÜRER  privat   Angebot   1500
# 4                     Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot   3600
# ...                                              ...     ...       ...    ...
# 371523                    Suche_t4___vito_ab_6_sitze  privat   Angebot   2200
# 371524         Smart_smart_leistungssteigerung_100ps  privat   Angebot   1199
# 371525            Volkswagen_Multivan_T4_TDI_7DC_UY2  privat   Angebot   9200
# 371526                        VW_Golf_Kombi_1_9l_TDI  privat   Angebot   3400
# 371527  BMW_M135i_vollausgestattet_NP_52.720____Euro  privat   Angebot  28990
#
# ...

# %%
df['name'].value_counts()
# Out:
# name
# Ford_Fiesta                                                         657
# BMW_318i                                                            627
# Opel_Corsa                                                          622
# Volkswagen_Golf_1.4                                                 603
# BMW_316i                                                            523
#                                                                    ...
# Subaru_Justy_1.3                                                      1
# OPEL_CORSA_B__ECO_SWING__TÜV_1/17_8fach_Bereifung/Schiebedach/CD      1
# Ford_C___Max_Titanium_1_0_L_EcoBoost                                  1
# VW_Derby_Bj_80__Scheunenfund                                          1
# BMW_316i___e36_Limousine___Bastlerfahrzeug__Export                    1
# Name: count, Length: 233531, dtype: int64

# %%
# muitos nomes diferentes
df = df.drop('name', axis=1)

# %%
df['seller'].value_counts()
# Out:
# seller
# privat        371525
# gewerblich         3
# Name: count, dtype: int64

# %%
# quase todos os carros com venda privada}
df = df.drop('seller', axis=1)

# %%
df['offerType'].value_counts()
# Out:
# offerType
# Angebot    371516
# Gesuch         12
# Name: count, dtype: int64

# %%
# dados também muito desbalanceados
df = df.drop('offerType', axis=1)

# %% [markdown]
# ### Removendo valores inconsistentes

# %%
# removendo registros inconsistentes (preço muito baixo)
df = df[df['price'] > 10]

# %%
# removendo registros inconsistentes (preço errado para muito alto)
df = df[df['price'] < 350000]

# %% [markdown]
# ### Tratando de valores nulos

# %%
# registros com valor nulo em tipo do veículo
df.loc[pd.isnull(df['vehicleType'])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480     test         NaN                1993    manuell        0
# 16        300     test         NaN                2016        NaN       60
# 22       2900     test         NaN                2018    manuell       90
# 26       5555  control         NaN                2017    manuell      125
# 31        899  control         NaN                2016    manuell       60
# ...       ...      ...         ...                 ...        ...      ...
# 371495    180  control         NaN                1995        NaN        0
# 371504   2600  control         NaN                2005  automatik        0
# 371509   1900     test         NaN                2000    manuell      110
# 371519   5250  control         NaN                2016  automatik      150
# 371523   2200     test         NaN                2005        NaN        0
#
# ...

# %%
# vendo os tipos de veículos mais preenchidos
df['vehicleType'].value_counts()
# Out:
# vehicleType
# limousine     93614
# kleinwagen    78014
# kombi         65921
# bus           29699
# cabrio        22509
# coupe         18386
# suv           14477
# andere         3125
# Name: count, dtype: int64

# %%
# vendo a moda
df['vehicleType'].mode()
# Out:
# 0    limousine
# Name: vehicleType, dtype: object

# %%
# registros com valor nulo em tipo de câmbio
df.loc[pd.isnull(df['gearbox'])]
# Out:
#         price   abtest vehicleType  yearOfRegistration gearbox  powerPS  \
# 15        450     test  kleinwagen                1910     NaN        0
# 16        300     test         NaN                2016     NaN       60
# 32        245     test   limousine                1994     NaN        0
# 37       1500     test         NaN                2016     NaN        0
# 70       1200     test       coupe                2001     NaN        0
# ...       ...      ...         ...                 ...     ...      ...
# 371443   3300  control       kombi                2006     NaN        0
# 371460   3500  control         NaN                1995     NaN        0
# 371486    350  control  kleinwagen                1996     NaN       65
# 371495    180  control         NaN                1995     NaN        0
# 371523   2200     test         NaN                2005     NaN        0
#
#          model  kilometer  monthOfRegistration fuelType           brand  \
# ...

# %%
# contando os preenchimentos no tipo de cambio
df['gearbox'].value_counts()
# Out:
# gearbox
# manuell      266547
# automatik     75508
# Name: count, dtype: int64

# %%
# registros com valor nulo em modelo
df.loc[pd.isnull(df['model'])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 1       18300     test       coupe                2011    manuell      190
# 83        350  control  kleinwagen                1997    manuell       54
# 139      1450  control   limousine                1992    manuell      136
# 156      6799  control  kleinwagen                2009        NaN       60
# 165       500  control  kleinwagen                1999    manuell        0
# ...       ...      ...         ...                 ...        ...      ...
# 371399    560  control  kleinwagen                2001  automatik      170
# 371476   9400  control       kombi                2007    manuell      200
# 371495    180  control         NaN                1995        NaN        0
# 371509   1900     test         NaN                2000    manuell      110
# 371523   2200     test         NaN                2005        NaN        0
#
# ...

# %%
# contando os preenchimentos nos modelos
df['model'].value_counts()
# Out:
# model
# golf               28989
# andere             25560
# 3er                19905
# polo               12604
# corsa              12149
#                    ...
# serie_2                8
# rangerover             6
# serie_3                3
# serie_1                1
# discovery_sport        1
# Name: count, Length: 251, dtype: int64

# %%
# registros com valor nulo em tipo de combustivel
df.loc[pd.isnull(df['fuelType'])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 9         999     test  kleinwagen                1998    manuell      101
# 13       2500  control       kombi                2004    manuell      131
# 26       5555  control         NaN                2017    manuell      125
# 36       1600  control      andere                1991    manuell       75
# 41       7500  control   limousine                2002  automatik      306
# ...       ...      ...         ...                 ...        ...      ...
# 371496   3850     test      cabrio                2006    manuell      108
# 371504   2600  control         NaN                2005  automatik        0
# 371509   1900     test         NaN                2000    manuell      110
# 371519   5250  control         NaN                2016  automatik      150
# 371523   2200     test         NaN                2005        NaN        0
#
# ...

# %%
# contando os preenchimentos em tipo de combustivel
df['fuelType'].value_counts()
# Out:
# fuelType
# benzin     217582
# diesel     106002
# lpg          5222
# cng           557
# hybrid        271
# andere        165
# elektro       101
# Name: count, dtype: int64

# %%
# registros com valor nulo em danos não reparados
df.loc[pd.isnull(df['notRepairedDamage'])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480     test         NaN                1993    manuell        0
# 2        9800     test         suv                2004  automatik      163
# 8       14500  control         bus                2014    manuell      125
# 9         999     test  kleinwagen                1998    manuell      101
# 12        999  control       kombi                1995    manuell      115
# ...       ...      ...         ...                 ...        ...      ...
# 371507   5999     test       kombi                2005    manuell      140
# 371514    999  control      cabrio                2000    manuell       95
# 371515   1690     test       kombi                2004    manuell       55
# 371523   2200     test         NaN                2005        NaN        0
# 371526   3400     test       kombi                2002    manuell      100
#
# ...

# %%
# contando os preenchimentos em danos não reparados
df['notRepairedDamage'].value_counts()
# Out:
# notRepairedDamage
# nein    259301
# ja       34004
# Name: count, dtype: int64

# %%
# dicionario para preencher os valores vazios com as modas (valores mais preenchidos para cada categoria)
values = {
    'vehicleType': 'limousine',
    'gearbox': 'manuell',
    'model': 'golf',
    'fuelType': 'benzin',
    'notRepairedDamage': 'nein'
}

# %%
# preenchendo os valores vazios
df = df.fillna(value=values)
df
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480     test   limousine                1993    manuell        0
# 1       18300     test       coupe                2011    manuell      190
# 2        9800     test         suv                2004  automatik      163
# 3        1500     test  kleinwagen                2001    manuell       75
# 4        3600     test  kleinwagen                2008    manuell       69
# ...       ...      ...         ...                 ...        ...      ...
# 371523   2200     test   limousine                2005    manuell        0
# 371524   1199     test      cabrio                2000  automatik      101
# 371525   9200     test         bus                1996    manuell      102
# 371526   3400     test       kombi                2002    manuell      100
# 371527  28990  control   limousine                2013    manuell      320
#
# ...

# %%
# contando os valores nulos de cada coluna
df.isnull().sum()
# Out:
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# model                  0
# kilometer              0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# dtype: int64

# %% [markdown]
# ### Separando os atributos em previsores e resposta

# %%
X = df.iloc[:, 1:12].values
X
# Out:
# array([['test', 'limousine', 1993, ..., 'benzin', 'volkswagen', 'nein'],
#        ['test', 'coupe', 2011, ..., 'diesel', 'audi', 'ja'],
#        ['test', 'suv', 2004, ..., 'diesel', 'jeep', 'nein'],
#        ...,
#        ['test', 'bus', 1996, ..., 'diesel', 'volkswagen', 'nein'],
#        ['test', 'kombi', 2002, ..., 'diesel', 'volkswagen', 'nein'],
#        ['control', 'limousine', 2013, ..., 'benzin', 'bmw', 'nein']],
#       dtype=object)

# %%
y = df.iloc[:, 0].values
y
# Out:
# array([  480, 18300,  9800, ...,  9200,  3400, 28990])

# %% [markdown]
# ### Tratando os valores categoricos

# %%
# vendo as marcas de veículos
df['brand'].value_counts()
# Out:
# brand
# volkswagen        76755
# bmw               38982
# opel              38557
# mercedes_benz     34498
# audi              31884
# ford              24761
# renault           17367
# peugeot           10777
# fiat               9339
# seat               6815
# skoda              5572
# mazda              5529
# smart              5159
# citroen            5038
# nissan             4893
# toyota             4616
# hyundai            3585
# mini               3354
# sonstige_autos     3331
# volvo              3229
# mitsubishi         2956
# honda              2726
# kia                2494
# suzuki             2274
# alfa_romeo         2250
# porsche            2154
# chevrolet          1791
# chrysler           1373
# dacia               889
# jeep                784
# daihatsu            774
# land_rover          759
# subaru              746
# jaguar              603
# daewoo              530
# saab                516
# trabant             489
# lancia              467
# ...

# %%
# transformando cada coluna do dataset em uma matriz binária
ohe = ColumnTransformer(transformers=[('OneHot', OneHotEncoder(), [0, 1, 3, 5, 8, 9, 10])], remainder='passthrough')

# %%
# aplicando a transformação
X = ohe.fit_transform(X).toarray()

# %%
# vendo o formato do dataframe original
df.shape
# Out:
# (359291, 12)

# %%
# vendo o formato do novo dataframe
X.shape
# Out:
# (359291, 316)

# %%
# criando a rede neural de regressão
regressor = Sequential([
    tf.keras.layers.InputLayer(shape=(316,)),
    tf.keras.layers.Dense(units=158, activation='relu'),
    tf.keras.layers.Dense(units=158, activation='relu'),
    tf.keras.layers.Dense(units=1, activation='linear')
])
# Out:
# 2026-02-05 18:07:32.323943: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
# sumário
regressor.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 158)            │        50,086 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 158)            │        25,122 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           159 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 75,367 (294.40 KB)
#  Trainable params: 75,367 (294.40 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# compilando
regressor.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
# fazendo o treinamento
regressor.fit(X, y, batch_size=300, epochs=100)
# Out:
# Epoch 1/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 3779.4617 - mean_absolute_error: 3779.4617
# Epoch 2/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 3200.7175 - mean_absolute_error: 3200.7175
# Epoch 3/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 2973.3704 - mean_absolute_error: 2973.3708
# Epoch 4/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 2849.0256 - mean_absolute_error: 2849.0256
# Epoch 5/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 2782.9985 - mean_absolute_error: 2782.9985
# Epoch 6/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 2741.6152 - mean_absolute_error: 2741.6152
# Epoch 7/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 2694.3491 - mean_absolute_error: 2694.3491
# Epoch 8/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 2654.5740 - mean_absolute_error: 2654.5740
# Epoch 9/100
# 1198/1198 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 2613.3857 - mean_absolute_error: 2613.3855
# ...

# %%
# fazendo as previsões
predict = regressor.predict(X)
# Out:
# 11228/11228 ━━━━━━━━━━━━━━━━━━━━ 13s 1ms/step

# %%
# vendo os resultados
predict
# Out:
# array([[  806.7043],
#        [ 9509.958 ],
#        [11917.392 ],
#        ...,
#        [ 6856.9365],
#        [ 3369.5342],
#        [25099.72  ]], dtype=float32)

# %%
# vendo as respostas corretas
y
# Out:
# array([  480, 18300,  9800, ...,  9200,  3400, 28990])

# %%
# media dos preções
y.mean()
# Out:
# np.float64(5916.833945186492)

# %%
# media das previsões
predict.mean()
# Out:
# np.float32(5079.8486)
