# %%
import keras
import numpy as np
import tensorflow as tf
import sklearn
# Out:
# /home/liperasz/anaconda3/envs/Card-16/lib/python3.11/site-packages/sklearn/utils/__init__.py:17: UserWarning: A NumPy version >=1.26.4 and <2.7.0 is required for this version of SciPy (detected version 1.25.2)
#   from scipy.sparse import issparse

# %%
keras.__version__, np.__version__, tf.__version__, sklearn.__version__
# Out:
# ('3.4.1', '1.25.2', '2.16.1', '1.2.2')

# %%
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import InputLayer, Dense, Flatten, Conv2D, MaxPooling2D
from keras import utils as np_utils
from sklearn.model_selection import StratifiedKFold

# %%
# pré processamento

# baixando o dataset
(X, y), (X_test, y_test) = mnist.load_data()
# alterando para o formato com 1 camada de profundidade
X = X.reshape(X.shape[0], 28, 28, 1)
# convertendo para float
X = X.astype('float32')
# normalizando
X /= 255
# categorizando
y = np_utils.to_categorical(y, 10)

# %%
# reprodutibilidade
seed = 5
np.random.seed(seed)

# %%
# definindo os parametros de separação
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)

# %%
# mostrando os indices dos valores que vão ser utilizados para treinar e testar em cada uma das 5 separações
results = []
for index_train, index_test in kfold.split(X, np.zeros(shape=(y.shape[0],1))):
    print('Index Train: ', index_train, 'Index Test: ', index_test)
    neural_network = Sequential()
    neural_network.add(InputLayer(shape=(28,28,1)))
    neural_network.add(Conv2D(32, (3,3), activation='relu'))
    neural_network.add(MaxPooling2D(pool_size=(2,2)))
    neural_network.add(Flatten())
    neural_network.add(Dense(units=128, activation='relu'))
    neural_network.add(Dense(units=10, activation='softmax'))
    neural_network.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    neural_network.fit(X[index_train], y[index_train], batch_size=128, epochs=5)
    accuracy = neural_network.evaluate(X[index_test], y[index_test])
    results.append(accuracy[1])
# Out:
# Index Train:  [    0     1     2 ... 59997 59998 59999] Index Test:  [    5     7    10 ... 59983 59985 59993]
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.8733 - loss: 0.4911
# Epoch 2/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.9776 - loss: 0.0762
# Epoch 3/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9853 - loss: 0.0494
# Epoch 4/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9894 - loss: 0.0349
# Epoch 5/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9913 - loss: 0.0279
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9807 - loss: 0.0693
# Index Train:  [    1     2     5 ... 59995 59996 59999] Index Test:  [    0     3     4 ... 59989 59997 59998]
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - accuracy: 0.8568 - loss: 0.4903
# Epoch 2/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9755 - loss: 0.0834
# Epoch 3/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9840 - loss: 0.0543
# Epoch 4/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9893 - loss: 0.0380
# Epoch 5/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.9920 - loss: 0.0284
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9871 - loss: 0.0444
# Index Train:  [    0     1     3 ... 59996 59997 59998] Index Test:  [    2    27    33 ... 59991 59995 59999]
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8567 - loss: 0.5068
# Epoch 2/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9752 - loss: 0.0869
# Epoch 3/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9851 - loss: 0.0522
# Epoch 4/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9881 - loss: 0.0399
# Epoch 5/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9906 - loss: 0.0307
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9862 - loss: 0.0545
# Index Train:  [    0     2     3 ... 59997 59998 59999] Index Test:  [    1     6     9 ... 59967 59975 59977]
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8597 - loss: 0.5158
# Epoch 2/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9756 - loss: 0.0885
# Epoch 3/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9858 - loss: 0.0498
# Epoch 4/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9890 - loss: 0.0378
# Epoch 5/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9918 - loss: 0.0282
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9827 - loss: 0.0612
# Index Train:  [    0     1     2 ... 59997 59998 59999] Index Test:  [   12    16    53 ... 59992 59994 59996]
# Epoch 1/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8666 - loss: 0.5032
# Epoch 2/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9755 - loss: 0.0870
# Epoch 3/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.9838 - loss: 0.0535
# Epoch 4/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9890 - loss: 0.0370
# Epoch 5/5
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9917 - loss: 0.0266
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9855 - loss: 0.0522
